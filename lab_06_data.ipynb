# %% [markdown]
# <a href="https://colab.research.google.com/github/Vyshnavisangaraboina/DATA_MINING/blob/main/lab_06_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn .decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
#step 1: load the iris dataset
iris = load_iris()
X = iris.data #Features
Y = iris.target #Labels

# %%
#step 2: preprocess the data (standardization)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(S)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(3, 3))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=Y, cmap='viridis', edgecolor='k',s=100)
plt.title('PCA of Iris Dataset (2 components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Target Class')
plt.show()

# %%
# Optimal:Explained Variance Ratio
print("explained_Variance_Ratio of Each component:")
print(pca.explained_variance_ratio_)
# Out:
# explained_Variance_Ratio of Each component:
# [0.72962445 0.22850762]
